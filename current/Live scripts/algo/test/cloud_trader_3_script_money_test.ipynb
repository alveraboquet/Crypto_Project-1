# %%
from sys import displayhook
from binance.client import Client
from binance.enums import *
import pandas as pd
import time
from datetime import datetime
from sqlalchemy import create_engine
import numpy as np
from math import log10

def getminutedata(symbol, interval, start):
    frame = pd.DataFrame(client.get_historical_klines(symbol,
                                                        interval,
                                                        start + ' min ago UTC'))
    frame = frame.iloc[:,:6]                                                    
    frame.columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']
    frame = frame.set_index('Time')
    frame.index = pd.to_datetime(frame.index, unit= 'ms')
    frame = frame.astype(float)
    return frame.reset_index()

if __name__ == "__main__":

    api_key = 'ihvXWbHvvDrYuroIJOS9ANW6X7tv5OQSYibLLloKyIGui0w93Q5yUJOBZclnNL5D'
    api_secret = 'uzmKBJ3lmVS4TsTl2AOHVJOYTFfLM5qrg00vAqUyTYbSjiy7BDPlTpaq2Oy7qdo2'
    client = Client(api_key, api_secret)
    db_data = 'mysql+mysqldb://' + 'admin' + ':' + '0323A8E3DB' + '@' + 'coin-database-1-instance-1.c9hqcydvu19f.us-east-1.rds.amazonaws.com' + ':3306/' + 'crypto_db' + '?charset=utf8mb4'
    engine = create_engine(db_data)

    check_date = pd.read_sql_query("SELECT MAX(date_request) FROM crypto_trend", engine) 
    date_recent_checked = str(check_date.iloc[0, 0])

    trend_table_status = pd.read_sql_query("show table status like 'crypto_trend'", engine)
    trend_table_rowcount_old = trend_table_status['Rows'].values[0]

    cryptoString = 'SELECT * FROM crypto'
    crypto_table = pd.read_sql_query(cryptoString, engine)
    full_id_list = crypto_table.id.astype(int).tolist()

    #setup variables
    maxholds = 3
    trades = [[],[],[],[]]
    tradedata = []
    buyPrice  = [0] * (len(full_id_list))
    sellPrice = [0] * (len(full_id_list))
    tradeBuy  = [0] * (len(full_id_list))
    tradeSell = [0] * (len(full_id_list))
    buyTime   = [0] * (len(full_id_list))
    sellTime  = [0] * (len(full_id_list))
    holding = [False] * (len(full_id_list))
    qty = [0] * (len(full_id_list))
    buy_ids = []
    buy_threshold = 80
    sell_threshold = 10


    waiting = True
    check_data = False
    # need async here? or while loop with 2 functions
    while(True):

        if(waiting):
            if datetime.now().minute < 20:
                trend_table_status = pd.read_sql_query("show table status like 'crypto_trend'", engine)
                trend_table_rowcount_new = trend_table_status['Rows'].values[0]
                if (trend_table_rowcount_new > trend_table_rowcount_old):
                    check_data = True
                    waiting = False
                else:
                    time.sleep(5)
            else:
                time.sleep(60)

        if(check_data):
            date_last_checked = date_recent_checked
            new_trends_string = f"SELECT * FROM crypto_trend WHERE date_request > '{date_last_checked}' ORDER BY date_request, crypto_id, date"
            new_trends = pd.read_sql_query(new_trends_string, engine)
            #update to ensure that if the count increased inbetween the request for count and request for data, does not re-check
            trend_table_rowcount_old = pd.read_sql_query("show table status like 'crypto_trend'", engine)['Rows'].values[0]

            if new_trends.empty:
                #print(f"Dataframe empty for request: {new_trends_string}")
                check_data = False
                waiting = True
                continue

            date_recent_checked = new_trends.date_request.max()

            try:
                trends = new_trends.pivot(index="date", columns="crypto_id", values="hype") #unbeliiiiieveevevevable !! https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
            except:
                pd.set_option("display.max_rows", None, "display.max_columns", None)
                print(new_trends)
                continue

            #check buying and selling conditions
            check_100 = ((trends.iloc[-2] == 100))# | (trends.iloc[-1] == 100)) ##check trends with current time
            check_non0 = trends.iloc[0:-2].mean() > 7 
            check_peak = (trends.iloc[0:-10] < buy_threshold).all()
            trend_indicate_buy = np.logical_and.reduce((check_100, check_non0, check_peak), dtype=bool)

            curr_id_list = trends.columns.values
            check_upward_ids = [curr_id_list[i] for i in [i for i, x in enumerate(trend_indicate_buy) if x]]
            
            buy_ids = []
            if check_upward_ids:
                print(f"Indicate buy ids: {check_upward_ids} between {date_last_checked} : {date_recent_checked}")
                for key, crypto_id in enumerate(check_upward_ids):
                    value = getminutedata(crypto_table.loc[crypto_table['id'] == crypto_id]['ticker'].values[0], 
                                                        '15m',
                                                        '120')
                    close = value[['Time','Close']]                             
                    close.index = pd.to_datetime(close['Time'])
                    close = close.drop(columns=['Time'])
                    close = close.rename(columns={"Close": f"{crypto_id}"})
                    
                    if (key != 0):
                        closes = closes.join(close)
                    else:
                        closes = close
            
                increase = closes.diff(periods=6)
                check_increase = (increase.iloc[-1] >= 0)

                indicate_buy = check_increase[check_increase].index.values.astype(int)
                #print(f"Indicate buy ids: {indicate_buy} between {date_last_checked} : {date_recent_checked}")

                curr_NOT_holding_ids = [full_id_list[i] for i in [i for i, x in enumerate(np.logical_not(holding)) if x]]
                buy_ids = list(set(indicate_buy).intersection(curr_NOT_holding_ids))

            check_decrease = np.logical_or((trends.iloc[-1] < sell_threshold), (trends.iloc[-2] < sell_threshold))
            indicate_sell = check_decrease[check_decrease].index.values.astype(int)
            #print(f"Indicate sell ids: {indicate_sell} between {date_last_checked} : {date_recent_checked}")

            curr_holding_ids = [full_id_list[i] for i in [i for i, x in enumerate(holding) if x]]
            sell_ids = list(set(indicate_sell).intersection(curr_holding_ids))

            
            # Buy control
            if ((sum(holding) < maxholds) and buy_ids):
                for id in buy_ids:
                    if (sum(holding) < maxholds):
                        key = full_id_list.index(id)
                        ticker = crypto_table.loc[crypto_table['id'] == id]['ticker'].values[0]
                        tradetime = closes.index[-1]
                        
                        ################################################
                        currbal = float(client.get_asset_balance(asset='USDT')['free'])
                        buy_amt = round( currbal / (maxholds - sum(holding)), 2)
                        buy_amt = 60 ################changed ###############
                        liveprice = client.get_symbol_ticker(symbol=ticker)['price']
                        qty_pre = (buy_amt)/float(liveprice)
                        pricePrecision = -log10(float(client.get_symbol_info(ticker)['filters'][2]['stepSize']))
                        qty[id] = round(qty_pre, int(pricePrecision))
                        #################################################
                        buyorder = client.create_order(symbol=ticker,
                                                        side='BUY',
                                                        type='MARKET',
                                                        quantity = qty[id])
                        market_price = float(buyorder['fills'][0]['price'])
                        print(buyorder)
                        #qty[id] = buyorder['fills'][0]['qty']

                        ####################################################
                        buyPrice[key] = closes.loc[tradetime,str(id)]
                        buyTime[key] = tradetime
                        holding[key] = True


                        print(f"Purchased {ticker} id {id}  at {buyPrice[key]} (marketprice = {market_price}) - {tradetime}")
                    else:
                        continue
            # Sell control
            if (sell_ids):
                for id in sell_ids:
                    ticker = crypto_table.loc[crypto_table['id'] == id]['ticker'].values[0]
                    value = getminutedata(ticker, 
                                                        '15m',
                                                        '120')
                    close = value[['Time','Close']]                             
                    close.index = pd.to_datetime(close['Time'])
                    close = close.drop(columns=['Time'])
                    # Sell execute function binance using ticker
                    key = full_id_list.index(id)
                    tradetime = close.index[-1]
                    sellPrice[key] = close.loc[tradetime, 'Close']
                    sellTime[key] = tradetime
                    ###############################
                    sellorder = client.create_order(symbol=ticker,
                            side='SELL', 
                            type= 'MARKET', 
                            quantity = qty[id])
                    market_price = float(sellorder['fills'][0]['price'])
                    print(sellorder)
                    ##################################
                    print(f"Trade completed: {ticker} id = {id} | open = {buyPrice[key]} at {buyTime[key]} | close = {sellPrice[key]} at {sellTime[key]} | profit = {(sellPrice[key]/buyPrice[key])}%  (marketprice = {market_price})")

                    # upload to database
                    quantity = 0
                    trade = (id, buyTime[key], buyPrice[key], sellTime[key], sellPrice[key], str(sellTime[key] - buyTime[key]),  sellPrice[key]/buyPrice[key], quantity)
                    index_names = ['crypto_id', 'date_buy', 'price_buy', 'date_sell', 'price_sell', 'trade_time', 'trade_return', 'quantity']
                    result = pd.DataFrame([trade],columns=index_names)


                    #########################
                    result.to_sql("crypto_trades_ev2", engine, if_exists="append", index=False)
                    ##########################


                    # tradedata.append([id, buyTime[key], sellTime[key], buyPrice[key], sellPrice[key], (sellPrice[key]/buyPrice[key]) ])
                    holding[key] = False

            check_data = False
            waiting = True
            # Calculate profit
            # tradedata = np.array(tradedata)
            # scaled = ((tradedata[:,5] - 1) * 1/maxholds) + 1
            # scaled.prod()
# Out:
# Indicate buy ids: [36, 200, 302] between 2022-04-05 08:07:32 : 2022-04-05 09:02:04
# {'symbol': 'ZENUSDT', 'orderId': 449195697, 'orderListId': -1, 'clientOrderId': 'o2BY8cfQmxR6LVATspgjDy', 'transactTime': 1649149404534, 'price': '0.00000000', 'origQty': '1.22000000', 'executedQty': '1.22000000', 'cummulativeQuoteQty': '59.76780000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '48.99000000', 'qty': '1.22000000', 'commission': '0.00009836', 'commissionAsset': 'BNB', 'tradeId': 32027158}]}
# Purchased ZENUSDT id 302  at 48.99 (marketprice = 48.99) - 2022-04-05 09:00:00
# Indicate buy ids: [171] between 2022-04-05 10:05:19 : 2022-04-05 10:06:38
# {'symbol': 'MBOXUSDT', 'orderId': 167626688, 'orderListId': -1, 'clientOrderId': 'x9ZRmessVLrnaN34IXkZri', 'transactTime': 1649153715471, 'price': '0.00000000', 'origQty': '15.40000000', 'executedQty': '15.40000000', 'cummulativeQuoteQty': '60.01380000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '3.89700000', 'qty': '15.40000000', 'commission': '0.00009855', 'commissionAsset': 'BNB', 'tradeId': 28122729}]}
# Purchased MBOXUSDT id 171  at 3.89 (marketprice = 3.897) - 2022-04-05 10:15:00
# Indicate buy ids: [141, 177, 200, 229, 278, 284] between 2022-04-05 10:06:38 : 2022-04-05 11:02:04
# {'symbol': 'RNDRUSDT', 'orderId': 37408459, 'orderListId': -1, 'clientOrderId': 'pTg3DWeyP84tH7TPW2y3dE', 'transactTime': 1649156624935, 'price': '0.00000000', 'origQty': '20.73000000', 'executedQty': '20.73000000', 'cummulativeQuoteQty': '59.99262000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '2.89400000', 'qty': '20.73000000', 'commission': '0.00009867', 'commissionAsset': 'BNB', 'tradeId': 4560792}]}
# Purchased RNDRUSDT id 229  at 2.894 (marketprice = 2.894) - 2022-04-05 11:00:00
# {'symbol': 'RNDRUSDT', 'orderId': 37409493, 'orderListId': -1, 'clientOrderId': '21IPiOxK5sUZ87KshNyVKZ', 'transactTime': 1649157573435, 'price': '0.00000000', 'origQty': '20.73000000', 'executedQty': '20.73000000', 'cummulativeQuoteQty': '60.19992000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '2.90400000', 'qty': '20.73000000', 'commission': '0.00009876', 'commissionAsset': 'BNB', 'tradeId': 4560836}]}
# Trade completed: RNDRUSDT id = 229 | open = 2.894 at 2022-04-05 11:00:00 | close = 2.908 at 2022-04-05 11:15:00 | profit = 1.004837595024188%  (marketprice = 2.904)
# Indicate buy ids: [97, 200] between 2022-04-05 11:07:52 : 2022-04-05 12:02:04
# {'symbol': 'PEOPLEUSDT', 'orderId': 183298544, 'orderListId': -1, 'clientOrderId': '4v9TcsDhqKazeqqLqH36m3', 'transactTime': 1649160202440, 'price': '0.00000000', 'origQty': '882.40000000', 'executedQty': '882.40000000', 'cummulativeQuoteQty': '60.00320000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '0.06800000', 'qty': '367.70000000', 'commission': '0.00004095', 'commissionAsset': 'BNB', 'tradeId': 12357567}, {'price': '0.06800000', 'qty': '514.70000000', 'commission': '0.00005732', 'commissionAsset': 'BNB', 'tradeId': 12357568}]}
# Purchased PEOPLEUSDT id 200  at 0.068 (marketprice = 0.068) - 2022-04-05 12:00:00
# Indicate buy ids: [171] between 2022-04-05 12:04:26 : 2022-04-05 12:05:43
# Indicate buy ids: [128, 150] between 2022-04-05 12:05:43 : 2022-04-05 13:02:04
# {'symbol': 'PEOPLEUSDT', 'orderId': 183368079, 'orderListId': -1, 'clientOrderId': 'zpMepksuLUSWGCDU8NN9je', 'transactTime': 1649163814165, 'price': '0.00000000', 'origQty': '882.40000000', 'executedQty': '882.40000000', 'cummulativeQuoteQty': '60.88560000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '0.06900000', 'qty': '882.40000000', 'commission': '0.00009991', 'commissionAsset': 'BNB', 'tradeId': 12363762}]}
# Trade completed: PEOPLEUSDT id = 200 | open = 0.068 at 2022-04-05 12:00:00 | close = 0.0691 at 2022-04-05 13:00:00 | profit = 1.0161764705882352%  (marketprice = 0.069)
# Indicate buy ids: [150] between 2022-04-05 13:07:11 : 2022-04-05 14:02:04
# Indicate buy ids: [298] between 2022-04-05 14:09:05 : 2022-04-05 15:02:05
# Indicate buy ids: [92, 132, 187] between 2022-04-05 15:06:22 : 2022-04-05 16:02:05
# {'symbol': 'NMRUSDT', 'orderId': 131497472, 'orderListId': -1, 'clientOrderId': '5Q7sjkIPX8Ftkw4sYzl2X1', 'transactTime': 1649174601398, 'price': '0.00000000', 'origQty': '1.94000000', 'executedQty': '1.94000000', 'cummulativeQuoteQty': '59.91380000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '30.88000000', 'qty': '1.28000000', 'commission': '0.00006603', 'commissionAsset': 'BNB', 'tradeId': 9521659}, {'price': '30.89000000', 'qty': '0.66000000', 'commission': '0.00003404', 'commissionAsset': 'BNB', 'tradeId': 9521660}]}
# Purchased NMRUSDT id 187  at 30.91 (marketprice = 30.88) - 2022-04-05 16:00:00
# Indicate buy ids: [41, 82, 193, 232, 301] between 2022-04-05 16:07:13 : 2022-04-05 17:02:04
# {'symbol': 'NMRUSDT', 'orderId': 131500943, 'orderListId': -1, 'clientOrderId': '2jBRpoURQqg4MIjrA4oJFP', 'transactTime': 1649178205898, 'price': '0.00000000', 'origQty': '1.94000000', 'executedQty': '1.94000000', 'cummulativeQuoteQty': '60.02360000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '30.94000000', 'qty': '0.53000000', 'commission': '0.00002724', 'commissionAsset': 'BNB', 'tradeId': 9521810}, {'price': '30.94000000', 'qty': '0.53000000', 'commission': '0.00002724', 'commissionAsset': 'BNB', 'tradeId': 9521811}, {'price': '30.94000000', 'qty': '0.88000000', 'commission': '0.00004523', 'commissionAsset': 'BNB', 'tradeId': 9521812}]}
# Trade completed: NMRUSDT id = 187 | open = 30.91 at 2022-04-05 16:00:00 | close = 30.99 at 2022-04-05 17:00:00 | profit = 1.0025881591717891%  (marketprice = 30.94)
# Indicate buy ids: [171, 216] between 2022-04-05 17:04:47 : 2022-04-05 17:08:52
# Indicate buy ids: [92] between 2022-04-05 17:08:52 : 2022-04-05 18:02:04
# {'symbol': 'DOGEUSDT', 'orderId': 2448706031, 'orderListId': -1, 'clientOrderId': 'gwjqYl3WosNUFAIcBARxLP', 'transactTime': 1649181802894, 'price': '0.00000000', 'origQty': '353.00000000', 'executedQty': '353.00000000', 'cummulativeQuoteQty': '59.97470000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '0.16990000', 'qty': '219.00000000', 'commission': '0.00006193', 'commissionAsset': 'BNB', 'tradeId': 407620136}, {'price': '0.16990000', 'qty': '134.00000000', 'commission': '0.00003789', 'commissionAsset': 'BNB', 'tradeId': 407620137}]}
# Purchased DOGEUSDT id 92  at 0.1699 (marketprice = 0.1699) - 2022-04-05 18:00:00
# {'symbol': 'ZENUSDT', 'orderId': 449435596, 'orderListId': -1, 'clientOrderId': 'QQVN20S27k75aYkxqMBKxz', 'transactTime': 1649181803598, 'price': '0.00000000', 'origQty': '1.22000000', 'executedQty': '1.22000000', 'cummulativeQuoteQty': '57.40100000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '47.05000000', 'qty': '1.22000000', 'commission': '0.00009549', 'commissionAsset': 'BNB', 'tradeId': 32035995}]}
# Trade completed: ZENUSDT id = 302 | open = 48.99 at 2022-04-05 09:00:00 | close = 47.05 at 2022-04-05 18:00:00 | profit = 0.9604000816493161%  (marketprice = 47.05)
# Indicate buy ids: [205] between 2022-04-05 18:02:04 : 2022-04-05 18:03:28
# Indicate buy ids: [74, 193, 200] between 2022-04-05 18:05:52 : 2022-04-05 19:02:02
# Indicate buy ids: [73] between 2022-04-05 19:05:52 : 2022-04-05 19:09:08
# Indicate buy ids: [94, 192, 300] between 2022-04-05 19:09:08 : 2022-04-05 20:02:04
# {'symbol': 'OMUSDT', 'orderId': 72274620, 'orderListId': -1, 'clientOrderId': '7jHpjGvoPYccNeWa67JCHk', 'transactTime': 1649189006893, 'price': '0.00000000', 'origQty': '594.00000000', 'executedQty': '594.00000000', 'cummulativeQuoteQty': '60.05340000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'fills': [{'price': '0.10110000', 'qty': '594.00000000', 'commission': '0.00010014', 'commissionAsset': 'BNB', 'tradeId': 11296781}]}
# Purchased OMUSDT id 192  at 0.101 (marketprice = 0.1011) - 2022-04-05 20:00:00
# Indicate buy ids: [65] between 2022-04-05 20:03:31 : 2022-04-05 20:04:47
# Indicate buy ids: [36, 284, 298] between 2022-04-05 20:06:03 : 2022-04-05 21:02:04
# {'symbol': 'OMUSDT', 'orderId': 72282565, 'orderListId': -1, 'clientOrderId': 'AKH786kGrb4VwdizIttvcX', 'transactTime': 1649192604945, 'price': '0.00000000', 'origQty': '594.00000000', 'executedQty': '594.00000000', 'cummulativeQuoteQty': '59.93460000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'fills': [{'price': '0.10090000', 'qty': '594.00000000', 'commission': '0.00010020', 'commissionAsset': 'BNB', 'tradeId': 11297863}]}
# Trade completed: OMUSDT id = 192 | open = 0.101 at 2022-04-05 20:00:00 | close = 0.1009 at 2022-04-05 21:00:00 | profit = 0.999009900990099%  (marketprice = 0.1009)
# Indicate buy ids: [198] between 2022-04-05 21:07:04 : 2022-04-05 22:02:03
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1800'>1801</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1801'>1802</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1802'>1803</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1803'>1804</a>         )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a> if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\MySQLdb\cursors.py:206, in BaseCursor.execute(self, query, args)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=204'>205</a> assert isinstance(query, (bytes, bytearray))
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=205'>206</a> res = self._query(query)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=206'>207</a> return res
#
# File ~\anaconda3\lib\site-packages\MySQLdb\cursors.py:319, in BaseCursor._query(self, q)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=317'>318</a> self._result = None
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=318'>319</a> db.query(q)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=319'>320</a> self._do_get_result(db)
#
# File ~\anaconda3\lib\site-packages\MySQLdb\connections.py:254, in Connection.query(self, query)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/connections.py?line=252'>253</a>     query = bytes(query)
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/connections.py?line=253'>254</a> _mysql.connection.query(self, query)
#
# OperationalError: (2013, 'Lost connection to server during query')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# c:\Users\ellio\work\Crypto Project\Live scripts\cloud_trader_3_script_money_test.ipynb Cell 1' in <cell line: 22>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ellio/work/Crypto%20Project/Live%20scripts/cloud_trader_3_script_money_test.ipynb#ch0000000?line=74'>75</a> date_last_checked = date_recent_checked
#      <a href='vscode-notebook-cell:/c%3A/Users/ellio/work/Crypto%20Project/Live%20scripts/cloud_trader_3_script_money_test.ipynb#ch0000000?line=75'>76</a> new_trends_string = f"SELECT * FROM crypto_trend WHERE date_request > '{date_last_checked}' ORDER BY date_request, crypto_id, date"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ellio/work/Crypto%20Project/Live%20scripts/cloud_trader_3_script_money_test.ipynb#ch0000000?line=76'>77</a> new_trends = pd.read_sql_query(new_trends_string, engine)
#      <a href='vscode-notebook-cell:/c%3A/Users/ellio/work/Crypto%20Project/Live%20scripts/cloud_trader_3_script_money_test.ipynb#ch0000000?line=77'>78</a> #update to ensure that if the count increased inbetween the request for count and request for data, does not re-check
#      <a href='vscode-notebook-cell:/c%3A/Users/ellio/work/Crypto%20Project/Live%20scripts/cloud_trader_3_script_money_test.ipynb#ch0000000?line=78'>79</a> trend_table_rowcount_old = pd.read_sql_query("show table status like 'crypto_trend'", engine)['Rows'].values[0]
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:436, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=377'>378</a> """
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=378'>379</a> Read SQL query into a DataFrame.
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=379'>380</a>
#    (...)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=432'>433</a> parameter will be converted to UTC.
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=433'>434</a> """
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=434'>435</a> pandas_sql = pandasSQL_builder(con)
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=435'>436</a> return pandas_sql.read_query(
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=436'>437</a>     sql,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=437'>438</a>     index_col=index_col,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=438'>439</a>     params=params,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=439'>440</a>     coerce_float=coerce_float,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=440'>441</a>     parse_dates=parse_dates,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=441'>442</a>     chunksize=chunksize,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=442'>443</a>     dtype=dtype,
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=443'>444</a> )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1579, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1530'>1531</a> """
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1531'>1532</a> Read SQL query into a DataFrame.
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1532'>1533</a>
#    (...)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1574'>1575</a>
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1575'>1576</a> """
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1576'>1577</a> args = _convert_params(sql, params)
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1578'>1579</a> result = self.execute(*args)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1579'>1580</a> columns = result.keys()
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1581'>1582</a> if chunksize is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1424, in SQLDatabase.execute(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1421'>1422</a> def execute(self, *args, **kwargs):
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1422'>1423</a>     """Simple passthrough to SQLAlchemy connectable"""
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/pandas/io/sql.py?line=1423'>1424</a>     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/deprecations.py?line=398'>399</a> if not skip_warning:
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/deprecations.py?line=399'>400</a>     _warn_with_version(message, version, wtype, stacklevel=3)
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/deprecations.py?line=400'>401</a> return fn(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3146, in Engine.execute(self, statement, *multiparams, **params)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3127'>3128</a> """Executes the given construct and returns a
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3128'>3129</a> :class:`_engine.CursorResult`.
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3129'>3130</a>
#    (...)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3142'>3143</a>
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3143'>3144</a> """
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3144'>3145</a> connection = self.connect(close_with_result=True)
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=3145'>3146</a> return connection.execute(statement, *multiparams, **params)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1274, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1264'>1265</a> if isinstance(statement, util.string_types):
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1265'>1266</a>     util.warn_deprecated_20(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1266'>1267</a>         "Passing a string to Connection.execute() is "
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1267'>1268</a>         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1270'>1271</a>         "driver-level SQL string."
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1271'>1272</a>     )
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1273'>1274</a>     return self._exec_driver_sql(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1274'>1275</a>         statement,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1275'>1276</a>         multiparams,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1276'>1277</a>         params,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1277'>1278</a>         _EMPTY_EXECUTION_OPTS,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1278'>1279</a>         future=False,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1279'>1280</a>     )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1281'>1282</a> try:
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1282'>1283</a>     meth = statement._execute_on_connection
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1578, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1567'>1568</a>         (
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1568'>1569</a>             statement,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1569'>1570</a>             distilled_params,
#    (...)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1573'>1574</a>             statement, distilled_parameters, execution_options
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1574'>1575</a>         )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1576'>1577</a> dialect = self.dialect
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1577'>1578</a> ret = self._execute_context(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1578'>1579</a>     dialect,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1579'>1580</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1580'>1581</a>     statement,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1581'>1582</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1582'>1583</a>     execution_options,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1583'>1584</a>     statement,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1584'>1585</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1585'>1586</a> )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1587'>1588</a> if not future:
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1588'>1589</a>     if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1841'>1842</a>             branched.close()
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1843'>1844</a> except BaseException as e:
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1844'>1845</a>     self._handle_dbapi_exception(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1845'>1846</a>         e, statement, parameters, cursor, context
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1846'>1847</a>     )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1848'>1849</a> return result
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2023'>2024</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2024'>2025</a> elif should_wrap:
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2025'>2026</a>     util.raise_(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2026'>2027</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2027'>2028</a>     )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2028'>2029</a> else:
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1799'>1800</a>                 break
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1800'>1801</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1801'>1802</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1802'>1803</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1803'>1804</a>         )
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a> if self._has_events or self.engine._has_events:
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     self.dispatch.after_cursor_execute(
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>         cursor,
#    (...)
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1812'>1813</a>         context.executemany,
#    <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/base.py?line=1813'>1814</a>     )
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\MySQLdb\cursors.py:206, in BaseCursor.execute(self, query, args)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=202'>203</a>         raise ProgrammingError(str(m))
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=204'>205</a> assert isinstance(query, (bytes, bytearray))
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=205'>206</a> res = self._query(query)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=206'>207</a> return res
#
# File ~\anaconda3\lib\site-packages\MySQLdb\cursors.py:319, in BaseCursor._query(self, q)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=316'>317</a> db = self._get_db()
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=317'>318</a> self._result = None
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=318'>319</a> db.query(q)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=319'>320</a> self._do_get_result(db)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/cursors.py?line=320'>321</a> self._post_get_result()
#
# File ~\anaconda3\lib\site-packages\MySQLdb\connections.py:254, in Connection.query(self, query)
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/connections.py?line=251'>252</a> if isinstance(query, bytearray):
#     <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/connections.py?line=252'>253</a>     query = bytes(query)
# --> <a href='file:///c%3A/Users/ellio/anaconda3/lib/site-packages/MySQLdb/connections.py?line=253'>254</a> _mysql.connection.query(self, query)
#
# OperationalError: (MySQLdb._exceptions.OperationalError) (2013, 'Lost connection to server during query')
# [SQL: SELECT * FROM crypto_trend WHERE date_request > '2022-04-05 22:04:41' ORDER BY date_request, crypto_id, date]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
buy_amt = round( currbal / (maxholds - sum(holding)), 2)

# %%
sum(holding) < maxholds
# Out:
# False
